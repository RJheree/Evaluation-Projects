# %% [markdown]
# ## Name- Ranjan Pratap Singh                                                      DS2307

# %% [markdown]
# ## Global Power Plant Database
# ### Project Description
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.
# Key attributes of the database
# The database includes the following indicators:
#
# •	`country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
#
# •	`country_long` (text): longer form of the country designation
#
# •	`name` (text): name or title of the power plant, generally in Romanized form
#
# •	`gppd_idnr` (text): 10 or 12 character identifier for the power plant
#
# •	`capacity_mw` (number): electrical generating capacity in megawatts
#
# •	`latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# •	`longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
#
# •	`primary_fuel` (text): energy source used in primary electricity generation or export
#
# •	`other_fuel1` (text): energy source used in electricity generation or export
#
# •	`other_fuel2` (text): energy source used in electricity generation or export
#
# •	`other_fuel3` (text): energy source used in electricity generation or export
#
# •	 `commissioning_year` (number): year of plant operation, weighted by unit-capacity when data is available
#
# •	`owner` (text): majority shareholder of the power plant, generally in Romanized form
#
# •	`source` (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
#
# •	`url` (text): web document corresponding to the `source` field
#
# •	`geolocation_source` (text): attribution for geolocation information
#
# •	`wepp_id` (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
#
# •	`year_of_capacity_data` (number): year the capacity information was reported
#
# •	`generation_gwh_2013` (number): electricity generation in gigawatt-hours reported for the year 2013
#
# •	`generation_gwh_2014` (number): electricity generation in gigawatt-hours reported for the year 2014
#
# •	`generation_gwh_2015` (number): electricity generation in gigawatt-hours reported for the year 2015
#
# •	`generation_gwh_2016` (number): electricity generation in gigawatt-hours reported for the year 2016
#
# •	`generation_gwh_2017` (number): electricity generation in gigawatt-hours reported for the year 2017
#
# •	`generation_gwh_2018` (number): electricity generation in gigawatt-hours reported for the year 2018
#
# •	`generation_gwh_2019` (number): electricity generation in gigawatt-hours reported for the year 2019
#
# •	`generation_data_source` (text): attribution for the reported generation information
#
# •	`estimated_generation_gwh_2013` (number): estimated electricity generation in gigawatt-hours for the year 2013
#
# •	`estimated_generation_gwh_2014` (number): estimated electricity generation in gigawatt-hours for the year 2014
#
# •	`estimated_generation_gwh_2015` (number): estimated electricity generation in gigawatt-hours for the year 2015
#
# •	`estimated_generation_gwh_2016` (number): estimated electricity generation in gigawatt-hours for the year 2016
#
# •	`estimated_generation_gwh_2017` (number): estimated electricity generation in gigawatt-hours for the year 2017
#
# •	'estimated_generation_note_2013` (text): label of the model/method used to estimate generation for the year 2013
#
# •	`estimated_generation_note_2014` (text): label of the model/method used to estimate generation for the year 2014
#
# •	`estimated_generation_note_2015` (text): label of the model/method used to estimate generation for the year 2015
#
# •	`estimated_generation_note_2016` (text): label of the model/method used to estimate generation for the year 2016
#
# •	`estimated_generation_note_2017` (text): label of the model/method used to estimate generation for the year 2017
#
# Fuel Type Aggregation
# We define the "Fuel Type" attribute of our database based on common fuel categories.
# Prediction :   Make two prediction  1) Primary Fuel    2) capacity_mw

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv(r"C:\Users\RANJAN\Downloads\database_IND.csv")

# %% [markdown]
# ### Exploratory Data Analysis(EDA)  ----->

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %% [markdown]
# our dataset of Global Power Plant Database has 907 rows and 27 columns which are defined in project description. Our dataset has two target variable  1)Primary Fuel 2) capacity_mw  .
#
# Primary Fuel is of categorical nature so we will use classification model and capicity_mw is of numerical nature so we will use regression model to train , test and predict the dataset.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# here we can see that there are no duplicated valeus in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [markdown]
# here we can see that our dataset contain two dtpyes i.e. object and float and there are  null values in our data set  we will further check later for white spaces

# %%
df['commissioning_year'] = df['commissioning_year'].astype(str).str.replace('\.0', '')

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year            0
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
#  checking the values counts pf each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# IND    907
# Name: country, dtype: int64
#
#
# India    907
# Name: country_long, dtype: int64
#
#
# ACME Solar Tower           1
# RAICHUR                    1
# PRYAGRAJ (BARA) TPP        1
# PULICHINTALA               1
# PUNE MILL                  1
#                           ..
# KADANA                     1
# KADRA                      1
# KAHALGAON                  1
# KAIGA                      1
# iEnergy Theni Wind Farm    1
# Name: name, Length: 907, dtype: int64
#
#
# WRI1020239    1
# IND0000356    1
# IND0000346    1
# IND0000523    1
# WRI1019978    1
#              ..
# IND0000167    1
# IND0000168    1
# IND0000169    1
# IND0000170    1
# WRI1026761    1
# Name: gppd_idnr, Length: 907, dtype: int64
#
#
# 5.0       39
# 10.0      22
# 600.0     20
# 15.0      20
# 1200.0    19
#           ..
# 291.0      1
# 645.0      1
# 41.4       1
# 17.5       1
# 106.6      1
# Name: capacity_mw, Length: 361, dtype: int64
#
#
# 19.0004    3
# 24.1917    3
# 24.8747    2
# ...

# %%
df.replace("nan", np.nan, inplace=True)

# %%
df = df.drop(['other_fuel2','other_fuel3','wepp_id','generation_gwh_2013','generation_gwh_2019','estimated_generation_gwh'],axis =1)

# %%
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                   46
# longitude                  46
# primary_fuel                0
# other_fuel1               709
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014       509
# generation_gwh_2015       485
# generation_gwh_2016       473
# generation_gwh_2017       467
# generation_gwh_2018       459
# generation_data_source    458
# dtype: int64

# %%
df[['longitude', 'latitude','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018']] = df[['longitude', 'latitude','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018']].fillna(df[['longitude', 'latitude','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018']].mean())

# %%
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                    0
# longitude                   0
# primary_fuel                0
# other_fuel1               709
# commissioning_year        380
# owner                     565
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014         0
# generation_gwh_2015         0
# generation_gwh_2016         0
# generation_gwh_2017         0
# generation_gwh_2018         0
# generation_data_source    458
# dtype: int64

# %%
df[['other_fuel1', 'commissioning_year', 'owner','generation_data_source','geolocation_source']] = df[['other_fuel1', 'commissioning_year', 'owner','generation_data_source','geolocation_source']].fillna(df[['other_fuel1', 'commissioning_year', 'owner','generation_data_source','geolocation_source']].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                    0
# longitude                   0
# primary_fuel                0
# other_fuel1                 0
# commissioning_year          0
# owner                       0
# source                      0
# url                         0
# geolocation_source          0
# year_of_capacity_data     388
# generation_gwh_2014         0
# generation_gwh_2015         0
# generation_gwh_2016         0
# generation_gwh_2017         0
# generation_gwh_2018         0
# generation_data_source      0
# dtype: int64

# %%
df = df.drop(['year_of_capacity_data'],axis=1)

# %%
df.isnull().sum()
# Out:
# country                   0
# country_long              0
# name                      0
# gppd_idnr                 0
# capacity_mw               0
# latitude                  0
# longitude                 0
# primary_fuel              0
# other_fuel1               0
# commissioning_year        0
# owner                     0
# source                    0
# url                       0
# geolocation_source        0
# generation_gwh_2014       0
# generation_gwh_2015       0
# generation_gwh_2016       0
# generation_gwh_2017       0
# generation_gwh_2018       0
# generation_data_source    0
# dtype: int64

# %% [markdown]
# here we can see that there are no white spaces but there are null values so we will do various steps to fill these

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  generation_gwh_2014  \
# count   907.000000  907.000000  907.000000           907.000000
# mean    326.223755   21.197918   77.464907          2431.823590
# std     590.085456    6.079148    4.812291          2665.338608
# min       0.000000    8.168900   68.644700             0.000000
# 25%      16.725000   17.072000   74.388900          1211.362750
# 50%      59.200000   21.281800   76.979200          2431.823590
# 75%     385.250000   25.176450   79.206100          2431.823590
# max    4760.000000   34.649000   95.408000         28127.000000
#
#        generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# count           907.000000           907.000000           907.000000
# mean           2428.226946          2467.936859          2547.759305
# std            2859.349132          2877.890004          2921.502193
# min               0.000000             0.000000             0.000000
# ...

# %% [markdown]
# In description we have count,mean, standard deviation(STD) , minimum(min), 25%,50%(median),75%,maximum(max)
#
# as we can see that there is no negative value so our description of dataset is valid
#
# number of observations are same in all columns so there is no missing values
#
# if we compare mean with median i.e. 50%  apart from capacity_mw we can see  all the data have almost same so  the data is normally distributed
#
# if we see for outliers we can observe that some coulmn may contain outliers that we will check  later in this model

# %% [markdown]
# ### Data Visualization --->

# %%
sns.countplot(x='primary_fuel' , data = df )
plt.xlabel('primary_fuel',color = 'r')
plt.grid(axis ='y')
plt.show()
df['primary_fuel'].value_counts()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# here we can see that coal and hydro are mostly used primary fuel

# %%
sns.countplot(x='other_fuel1' , data = df )
plt.xlabel('other_fuel1',color = 'r')
plt.grid(axis ='y')
plt.show()
df['other_fuel1'].value_counts()
# Out:
# Oil             904
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %% [markdown]
# in otherfuel we will almost use oil

# %%
plt.figure(figsize=(30,10))
sns.countplot(x='commissioning_year' , data = df )
plt.xlabel('commissioning_year',color = 'r')
plt.xticks(rotation=90,fontsize=19)
plt.grid(axis ='y')
plt.show()
df['commissioning_year'].value_counts()
# Out:
# 2015    408
# 2013     25
# 2012     23
# 2016     19
# 2010     18
#        ...
# 1946      1
# 1956      1
# 1937      1
# 1949      1
# 1953      1
# Name: commissioning_year, Length: 73, dtype: int64

# %% [markdown]
# here almost all commissioning year are 2015

# %%
plt.figure(figsize=(30,10))
sns.countplot(x='owner' , data = df )
plt.xlabel('owner',color = 'r')
plt.xticks(rotation=90)
plt.grid(axis ='y')
plt.show()
df['owner'].value_counts()
# Out:
# Acc Acc ltd                                                    569
# Sterling Agro Industries ltd.                                    4
# Jk Cement ltd                                                    4
# Maharashtra State Power Generation Co Ltd (MAHAGENCO)            3
# Karnataka Power Corporation Limited                              3
#                                                               ...
# Sunkon Energy Private Limited                                    1
# West Bengal Energy Development Corporation Limited (WBEDCL)      1
# Energy Infratech Private Limited                                 1
# K. N. Ram                                                        1
# iEnergy Wind Farms                                               1
# Name: owner, Length: 280, dtype: int64

# %%
plt.figure(figsize=(30,10))
sns.countplot(x='source' , data = df )
plt.xlabel('source',color = 'r')
plt.xticks(rotation=90)
plt.grid(axis ='y')
plt.show()
df['source'].value_counts()
# Out:
# Central Electricity Authority                                  519
# CDM                                                            124
# Lancosola                                                       10
# National Renewable Energy Laboratory                             8
# National Thermal Power Corporation (NTPC)                        6
#                                                               ...
# Harsha Engineers Limited                                         1
# Godawari Energy ltd                                              1
# Sunkon Energy Private Limited                                    1
# West Bengal Energy Development Corporation Limited (WBEDCL)      1
# Yashwantrao Krishna ssk                                          1
# Name: source, Length: 191, dtype: int64

# %%
sns.countplot(x='geolocation_source' , data = df )
plt.xlabel('geolocation_source',color = 'r')
plt.grid(axis ='y')
plt.show()
df['geolocation_source'].value_counts()
# Out:
# WRI                                     784
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %% [markdown]
# here we can see in geolocation source are mostly is WRI

# %%
sns.countplot(x='generation_data_source' , data = df )
plt.xlabel('generation_data_source',color = 'r')
plt.grid(axis ='y')
plt.show()
df['generation_data_source'].value_counts()
# Out:
# Central Electricity Authority    907
# Name: generation_data_source, dtype: int64

# %%
sns.histplot(x='capacity_mw', data=df, kde=True, color='blue')
plt.show()

# %% [markdown]
# here we can see that data is positively skewed

# %%
sns.histplot(x='latitude', data=df, kde=True, color='blue')
plt.show()

# %% [markdown]
# here we can see that in latitude that data is normally distributed

# %%
sns.histplot(x='longitude', data=df, kde=True, color='blue')
plt.show()

# %% [markdown]
# here we can see that data is positively skewed

# %%
sns.histplot(x='generation_gwh_2014', data=df, kde=True, color='blue')
plt.show()

# %% [markdown]
# here we can see that data is positively skewed

# %%
sns.histplot(x='generation_gwh_2015', data=df, kde=True, color='blue')
plt.show()

# %% [markdown]
# here we can see that data is positively skewed

# %%
sns.histplot(x='generation_gwh_2016', data=df, kde=True, color='blue')
plt.show()

# %% [markdown]
# here we can see that data is positively skewed

# %%
sns.histplot(x='generation_gwh_2017', data=df, kde=True, color='blue')
plt.show()

# %% [markdown]
# here we can see that data is positively skewed

# %%
sns.histplot(x='generation_gwh_2018', data=df, kde=True, color='blue')
plt.show()

# %% [markdown]
# here we can see that data is positively skewed

# %%
sns.regplot(y='capacity_mw', x='latitude', data=df)
plt.show()

# %% [markdown]
# here we can see that most of the latitude have less than 500 capacity_mw

# %%
sns.regplot(y='capacity_mw', x='longitude', data=df)
plt.show()

# %% [markdown]
# here we can see that most of the longitude is under 700 capacity_mw and there is slightly positive relationship between two.

# %%
sns.stripplot(y='capacity_mw', x='primary_fuel', data=df)
plt.show()

# %% [markdown]
# here we can see that most the the coal has more capacity_mw than rest

# %%
sns.stripplot(y='capacity_mw', x='other_fuel1', data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation=90,fontsize=18 )
plt.grid(axis ='y')
sns.stripplot(y='capacity_mw', x='commissioning_year', data=df)
plt.show()

# %%
sns.stripplot(y='capacity_mw', x='geolocation_source', data=df)
plt.show()

# %% [markdown]
# here we can see that all  the geolocation_source are WRI and they have high capacity_mw

# %%
sns.regplot(y='capacity_mw', x='generation_gwh_2014', data=df)
plt.show()

# %% [markdown]
# here we can clearly see that both are positively correlated

# %%
sns.regplot(y='capacity_mw', x='generation_gwh_2015', data=df)
plt.show()

# %% [markdown]
# here we can clearly see that both are positively correlated

# %%
sns.regplot(y='capacity_mw', x='generation_gwh_2016', data=df)
plt.show()

# %% [markdown]
# here we can clearly see that both are positively correlated

# %%
sns.regplot(y='capacity_mw', x='generation_gwh_2017', data=df)
plt.show()

# %% [markdown]
# here we can clearly see that both are positively correlated

# %%
sns.regplot(y='capacity_mw', x='generation_gwh_2018', data=df)
plt.show()

# %% [markdown]
# here we can clearly see that both are positively correlated

# %%
sns.stripplot(y='latitude', x='primary_fuel', data=df)
plt.show()

# %% [markdown]
# here we can not see any clearly see any relationship

# %%
sns.stripplot(y='longitude', x='primary_fuel', data=df)
plt.show()

# %% [markdown]
# here we can see that Biomass,Oil,Nuclear,wind are mostly in less longitude

# %%
plt.figure(figsize=(30,10))
plt.xticks(fontsize=18 )
sns.countplot(x='geolocation_source' , data = df,hue='primary_fuel' )
plt.xlabel('geolocation_source',color = 'r')
plt.grid(axis ='y')
plt.show()
df['geolocation_source'].value_counts()
# Out:
# WRI                                     784
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %% [markdown]
# here we can see that coal and hydro are in WRI
# here industry about and National Renewable Energy Laboratory  only have Solar

# %%
plt.figure(figsize=(30,10))
plt.xticks(fontsize=18 )
sns.countplot(x='other_fuel1' , data = df,hue='primary_fuel' )
plt.xlabel('other_fuel1',color = 'r')
plt.grid(axis ='y')
plt.show()
df['other_fuel1'].value_counts()
# Out:
# Oil             904
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %% [markdown]
# here there is no significant relationship

# %%
sns.stripplot(y='generation_gwh_2014', x='primary_fuel', data=df)
plt.show()

# %% [markdown]
# here we can see that mostly coal used in generating electricity and it generated more energy

# %%
sns.stripplot(y='generation_gwh_2015', x='primary_fuel', data=df)
plt.show()

# %% [markdown]
# here we can see that mostly coal used in generating electricity and it generated more energy

# %%
sns.stripplot(y='generation_gwh_2016', x='primary_fuel', data=df)
plt.show()

# %% [markdown]
# here we can see that mostly coal used in generating electricity and it generated more energy

# %%
sns.stripplot(y='generation_gwh_2017', x='primary_fuel', data=df)
plt.show()

# %% [markdown]
# here we can see that mostly coal used in generating electricity and it generated more energy

# %%
sns.stripplot(y='generation_gwh_2018', x='primary_fuel', data=df)
plt.show()

# %% [markdown]
# here we can see that mostly coal used in generating electricity and it generated more energy

# %%
sns.pairplot(data = df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### -- Checking for Outliers

# %%
df1 = df.select_dtypes(exclude='object')

# %%
plt.figure(figsize=(20, 20), facecolor="pink")
plotnumber = 1
for i in df1.columns[:8]: 
    ax = plt.subplot(3, 3, plotnumber)  
    sns.boxplot(data=df1, y=i, palette='Set2_r')
    ax.set_xlabel(i)
    plotnumber += 1

plt.show()

# %% [markdown]
# here we can see that all the data except latitude have outliers

# %%
from scipy.stats import zscore
z = np.abs(zscore(df1))
z
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2014  \
# 0       0.548908  1.149805   0.878280         1.707094e-16
# 1       0.386977  0.587311   0.593788         1.707094e-16
# 2       0.486679  0.116179   1.682394         1.707094e-16
# 3       0.324240  0.439989   2.889052         6.809773e-01
# 4       2.498942  0.125479   1.027976         2.266352e-01
# ..           ...       ...        ...                  ...
# 902     2.159821  0.806975   0.022477         1.707094e-16
# 903     0.548060  1.366853   0.145644         1.707094e-16
# 904     0.509909  0.974707   0.391673         1.707094e-16
# 905     0.417498  0.518793   0.772866         1.707094e-16
# 906     0.525169  1.853834   0.002473         1.707094e-16
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0               0.000000             0.000000         1.557412e-16
# 1               0.000000             0.000000         1.557412e-16
# ...

# %%
np.where(z>3)
# Out:
# (array([ 15,  15,  15,  15,  15, 143, 143, 143, 143, 143, 143, 147, 158,
#         179, 183, 209, 209, 209, 209, 209, 209, 244, 308, 308, 308, 308,
#         308, 308, 323, 333, 340, 360, 363, 364, 364, 364, 364, 364, 364,
#         375, 416, 427, 482, 493, 493, 493, 493, 493, 493, 494, 494, 494,
#         494, 494, 494, 499, 519, 546, 577, 638, 648, 648, 648, 648, 648,
#         648, 657, 657, 657, 657, 657, 657, 695, 695, 695, 695, 695, 695,
#         721, 721, 721, 721, 724, 724, 724, 724, 724, 726, 726, 726, 726,
#         726, 726, 767, 786, 786, 786, 786, 786, 786, 788, 808, 808, 808,
#         808, 808, 808, 818, 847, 880, 880, 880, 880, 880, 880], dtype=int64),
#  array([0, 4, 5, 6, 7, 0, 3, 4, 5, 6, 7, 0, 3, 2, 2, 0, 3, 4, 5, 6, 7, 2,
#         0, 3, 4, 5, 6, 7, 2, 2, 2, 2, 0, 0, 3, 4, 5, 6, 7, 0, 2, 2, 0, 0,
#         3, 4, 5, 6, 7, 0, 3, 4, 5, 6, 7, 2, 2, 2, 2, 2, 0, 3, 4, 5, 6, 7,
#         0, 3, 4, 5, 6, 7, 0, 3, 4, 5, 6, 7, 3, 4, 5, 7, 3, 4, 5, 6, 7, 0,
# ...

# %%
df2= df[(z<3).all(axis=1)]

# %%
print('percentage of dataloss',((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# percentage of dataloss 4.299889746416759

# %% [markdown]
# here we have removed the outliers

# %% [markdown]
# ### -- Checking for Skewness

# %%
plt.figure(figsize=(20, 20), facecolor="pink")
plotnumber = 1
for i in df1.columns[:8]: 
    ax = plt.subplot(3, 3, plotnumber)  
    sns.distplot(df1[i])
    ax.set_xlabel(i)
    plotnumber += 1

plt.show()

# %%
df.skew()
# Out:
# capacity_mw            3.123576
# latitude              -0.149698
# longitude              1.141881
# commissioning_year          NaN
# generation_gwh_2014    5.035446
# generation_gwh_2015    5.364134
# generation_gwh_2016    5.068427
# generation_gwh_2017    5.110952
# generation_gwh_2018    4.937907
# dtype: float64

# %% [markdown]
# here we can see that some features are positevely skewed

# %%
df['longitude']=np.cbrt(df['longitude'])
df['generation_gwh_2014']=np.cbrt(df['generation_gwh_2014'])
df['generation_gwh_2015']=np.cbrt(df['generation_gwh_2015'])
df['generation_gwh_2016']=np.cbrt(df['generation_gwh_2016'])
df['generation_gwh_2017']=np.cbrt(df['generation_gwh_2017'])
df['generation_gwh_2018']=np.cbrt(df['generation_gwh_2018'])

# %%
df['capacity_mw']=np.cbrt(df['capacity_mw'])

# %%
df.skew()
# Out:
# capacity_mw            1.013378
# latitude              -0.149698
# longitude              1.002134
# commissioning_year          NaN
# generation_gwh_2014   -0.371187
# generation_gwh_2015   -0.269579
# generation_gwh_2016   -0.279323
# generation_gwh_2017   -0.331857
# generation_gwh_2018   -0.316915
# dtype: float64

# %% [markdown]
# here we removed the skewness

# %% [markdown]
# ### checking for correlation

# %%
correlation = df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(correlation , annot = True)
plt.show()

# %% [markdown]
# here we can see that all the features have positive relationship with target variable 'capacity_mw'.
# generation_gwh_2014,generation_gwh_2015,generation_gwh_2016,generation_gwh_2017,generation_gwh_2018 have high correlation with eachother we will check for multicollinearity later

# %% [markdown]
# ### --Using label encoder

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = label_encoder.fit_transform(df[column])

# %% [markdown]
# ### Seperating features and target variable(capacity_mw)

# %%
X= df.drop(['capacity_mw','country','country_long'], axis=1)
Y=df.capacity_mw

# %% [markdown]
# ### Scaling using Standard Scalar

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
X = pd.DataFrame(SS.fit_transform(X), columns = X.columns)
X
# Out:
#          name  gppd_idnr  latitude  longitude  primary_fuel  other_fuel1  \
# 0   -1.730142   0.779137  1.149805  -0.892687      1.225688     0.054303
# 1   -1.726323   0.252074  0.587311  -0.593158     -0.967877     0.054303
# 2   -1.722504   1.527719  0.116179  -1.760007      1.664401     0.054303
# 3   -1.718684  -1.730142  0.439989   2.808168     -0.529164     0.054303
# 4   -1.714865  -1.726323  0.125479   1.047925     -0.967877     0.054303
# ..        ...        ...       ...        ...           ...          ...
# 902  1.714865   0.145133 -0.806975  -0.002532     -0.967877     0.054303
# 903  1.718684   1.409321 -1.366853   0.168603      1.225688     0.054303
# 904  1.722504   1.672853 -0.974707  -0.382577      1.664401     0.054303
# 905  1.726323   0.328460  0.518793  -0.781270     -0.967877     0.054303
# 906  1.730142   1.615563 -1.853834   0.022940      1.664401     0.054303
#
#      commissioning_year     owner    source       url  geolocation_source  \
# ...

# %% [markdown]
# ### Checking for VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF values'] = [variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif
# Out:
#                   Features  VIF values
# 0                     name    1.511667
# 1                gppd_idnr    5.034313
# 2                 latitude    1.120241
# 3                longitude    1.268640
# 4             primary_fuel    3.987629
# 5              other_fuel1    1.032397
# 6       commissioning_year    1.964289
# 7                    owner    3.816461
# 8                   source    3.967728
# 9                      url    3.056582
# 10      geolocation_source    3.278520
# 11     generation_gwh_2014    4.526352
# 12     generation_gwh_2015    8.259938
# 13     generation_gwh_2016   12.303723
# 14     generation_gwh_2017   10.288660
# 15     generation_gwh_2018   11.289466
# 16  generation_data_source         NaN

# %% [markdown]
# we can see that there are high VIF in some features so we will remove some features

# %%
X = X.drop(['generation_gwh_2016'], axis = 1)

# %%
vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF values'] = [variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif
# Out:
#                   Features  VIF values
# 0                     name    1.511470
# 1                gppd_idnr    5.028664
# 2                 latitude    1.117287
# 3                longitude    1.256731
# 4             primary_fuel    3.987050
# 5              other_fuel1    1.030928
# 6       commissioning_year    1.943696
# 7                    owner    3.815998
# 8                   source    3.966517
# 9                      url    3.055029
# 10      geolocation_source    3.277528
# 11     generation_gwh_2014    4.501526
# 12     generation_gwh_2015    5.583267
# 13     generation_gwh_2017    9.591189
# 14     generation_gwh_2018   10.510038
# 15  generation_data_source         NaN

# %%
X = X.drop(['generation_gwh_2018'], axis = 1)

# %%
vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF values'] = [variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif
# Out:
#                   Features  VIF values
# 0                     name    1.511077
# 1                gppd_idnr    5.024089
# 2                 latitude    1.117259
# 3                longitude    1.256570
# 4             primary_fuel    3.979559
# 5              other_fuel1    1.016715
# 6       commissioning_year    1.943624
# 7                    owner    3.811488
# 8                   source    3.962925
# 9                      url    3.045777
# 10      geolocation_source    3.268987
# 11     generation_gwh_2014    4.444867
# 12     generation_gwh_2015    5.414313
# 13     generation_gwh_2017    3.240350
# 14  generation_data_source         NaN

# %% [markdown]
# here after removing some features we removed multicollinearity

# %% [markdown]
# ## Creating train test Split

# %%
from sklearn.model_selection import train_test_split
for i in range(1,100):
    X_train,X_test,Y_train,Y_test =train_test_split (X,Y, test_size = 0.25 , random_state = i)

# %% [markdown]
# #### importing necessary libraries for models

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor 
LR = LinearRegression()
RIG= Ridge()
SVM=SVR()
LS= Lasso()
RFR=RandomForestRegressor()
DTR = DecisionTreeRegressor()
abr = AdaBoostRegressor()
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Models

# %% [markdown]
# #### Lasso

# %%
LS.fit(X_train, Y_train)
y_pred = LS.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.22511394195856005

# %%
y_pred_testLS  = LS.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testLS ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.22080676520484444

# %%
mae = mean_absolute_error(Y_test, y_pred_testLS)
mse = mean_squared_error(Y_test, y_pred_testLS)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 2.227970363867363
# Mean Squared Error -->: 7.68871548758074
# Root Mean Squared Error-->: 2.772853311587315

# %% [markdown]
# #### Ridge

# %%
RIG.fit(X_train, Y_train)
y_pred = RIG.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.577938988471945

# %%
y_pred_testRIG  = RIG.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testRIG ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.5120940472952848

# %%
mae = mean_absolute_error(Y_test, y_pred_testRIG)
mse = mean_squared_error(Y_test, y_pred_testRIG)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 1.6886313067390455
# Mean Squared Error -->: 4.8144284209934
# Root Mean Squared Error-->: 2.1941805807620756

# %% [markdown]
# #### Support vector Regression (svm)

# %%
SVM.fit(X_train, Y_train)
y_pred = SVM.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.7037872401036207

# %%
y_pred_testSVM  = SVM.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testSVM ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.6367327370980425

# %%
mae = mean_absolute_error(Y_test, y_pred_testSVM)
mse = mean_squared_error(Y_test, y_pred_testSVM)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 1.3401473090023803
# Mean Squared Error -->: 3.5845519515317927
# Root Mean Squared Error-->: 1.8932913012877317

# %% [markdown]
# #### LInear Regression

# %%
LR.fit(X_train, Y_train)
y_pred = LR.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.5779459088802512

# %%
y_pred_testLR  = LR.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testLR ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.511758524284808

# %%
mae = mean_absolute_error(Y_test, y_pred_testLR)
mse = mean_squared_error(Y_test, y_pred_testLR)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 1.68954871198056
# Mean Squared Error -->: 4.8177392055996995
# Root Mean Squared Error-->: 2.19493489780442

# %% [markdown]
# #### DecisionTreeRegressor

# %%
DTR.fit(X_train, Y_train)
y_pred = DTR.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 1.0

# %%
y_pred_testDTR  = DTR.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testDTR ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.7923297712448465

# %%
mae = mean_absolute_error(Y_test, y_pred_testDTR)
mse = mean_squared_error(Y_test, y_pred_testDTR)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 1.0232115955134788
# Mean Squared Error -->: 2.0491929765778183
# Root Mean Squared Error-->: 1.4315002537819608

# %% [markdown]
# #### AdaBoostRegressor

# %%
abr.fit(X_train, Y_train)
y_pred = abr.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.8416345060273943

# %%
y_pred_testABR  = abr.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testABR ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.7721715826655573

# %%
mae = mean_absolute_error(Y_test, y_pred_testABR)
mse = mean_squared_error(Y_test, y_pred_testABR)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 1.21404681782251
# Mean Squared Error -->: 2.2481045813120417
# Root Mean Squared Error-->: 1.499368060654902

# %% [markdown]
# #### RandoForestRegressor

# %%
RFR.fit(X_train, Y_train)
y_pred = RFR.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.9800098066908766

# %%
y_pred_testRFR  = RFR.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testRFR ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.857073106488367

# %%
mae = mean_absolute_error(Y_test, y_pred_testRFR)
mse = mean_squared_error(Y_test, y_pred_testRFR)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 0.843256650684264
# Mean Squared Error -->: 1.4103359355059024
# Root Mean Squared Error-->: 1.1875756546451692

# %% [markdown]
# we will further understand which model is best predicting by using cross validation

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cscore1 = cross_val_score(LS,X,Y)
print('Cscore for Lasso-> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testLS)-cscore1.mean())
# Out:
# Cscore for Lasso->  [0.20508359 0.24701095 0.19092612 0.17639363 0.15652415]
# mean of cscore->  0.1951876900027423
# difference between R2 and cross validation score is 0.025619075202102132

# %%
cscore1 = cross_val_score(abr,X,Y)
print('Cscore for AdaBoost Regressor-> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testABR)-cscore1.mean())
# Out:
# Cscore for AdaBoost Regressor->  [0.73672025 0.79821679 0.74749282 0.81806201 0.80099203]
# mean of cscore->  0.7802967786751532
# difference between R2 and cross validation score is -0.008125196009595936

# %%
cscore1 = cross_val_score(LR,X,Y)
print('Cscore for Linaer Regression -> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testLR)-cscore1.mean())
# Out:
# Cscore for Linaer Regression ->  [0.53489637 0.53327745 0.53527488 0.57396872 0.52982967]
# mean of cscore->  0.5414494197958144
# difference between R2 and cross validation score is -0.029690895511006454

# %%
cscore1 = cross_val_score(RIG,X,Y)
print('Cscore for RIDGE-> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testRIG)-cscore1.mean())
# Out:
# Cscore for RIDGE->  [0.53605459 0.53381288 0.53501738 0.57376136 0.53042967]
# mean of cscore->  0.5418151765843804
# difference between R2 and cross validation score is -0.029721129289095538

# %%
cscore1 = cross_val_score(SVM,X,Y)
print('Cscore for Support Vector Model -> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testABR)-cscore1.mean())
# Out:
# Cscore for Support Vector Model ->  [0.65227913 0.64946596 0.61042354 0.70559485 0.63557341]
# mean of cscore->  0.650667377462435
# difference between R2 and cross validation score is 0.12150420520312233

# %%
cscore1 = cross_val_score(DTR,X,Y)
print('Cscore for Decision Tree Regressor -> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testDTR)-cscore1.mean())
# Out:
# Cscore for Decision Tree Regressor ->  [0.66881634 0.56295411 0.76496168 0.76040278 0.74181982]
# mean of cscore->  0.6997909498142141
# difference between R2 and cross validation score is 0.09253882143063241

# %%
cscore1 = cross_val_score(RFR,X,Y)
print('Cscore for RandomForest Regressor-> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testRFR)-cscore1.mean())
# Out:
# Cscore for RandomForest Regressor->  [0.81156587 0.81333492 0.80989404 0.88794287 0.86756088]
# mean of cscore->  0.8380597144213535
# difference between R2 and cross validation score is 0.019013392067013468

# %% [markdown]
# here after considering the Cscore we we choose RandomForestRegressor

# %% [markdown]
# ## Hyper parameter tuning

# %%
RFR.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
parameters = {
    'n_estimators': [100, 500, 1000],
    'criterion': ["squared_error", "absolute_error", "friedman_mse", "poisson"],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'max_features': ["sqrt", "log2", None, 0.5],
    }

# %%
GSC = GridSearchCV(RandomForestRegressor(),parameters,cv= 5)

# %%
GSC.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_depth': [None, 10, 20],
#                          'max_features': ['sqrt', 'log2', None, 0.5],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 500, 1000]})

# %%
GSC.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': None,
#  'max_features': 'log2',
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
RFR_final=RandomForestRegressor(criterion= 'friedman_mse',max_depth= None,max_features ='log2',n_estimators= 100,min_samples_split= 2)
RFR_final.fit(X_train, Y_train)
y_pred = RFR_final.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.9800583422675707

# %%
y_pred_testRFR  = RFR_final.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testRFR ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.8623900991559216

# %% [markdown]
# ## Model Saving

# %%
import joblib
joblib.dump(RFR_final, 'Global Power Plant Database(capacity_mw)')
# Out:
# ['Global Power Plant Database(capacity_mw)']

# %% [markdown]
# # Prediction

# %%
mymodel = joblib.load('Global Power Plant Database(capacity_mw)')
prdt = mymodel.predict(X_test)
prdt
# Out:
# array([ 6.97281878,  2.99981482,  2.36599379,  3.01471417,  4.5575795 ,
#         3.26958856, 10.58627383, 10.48184093,  6.92794775,  3.62559913,
#         1.72036817,  3.73491754, 10.24059832,  8.94620625,  2.98329517,
#         5.61410858,  6.7431873 ,  2.62459054,  6.83164243,  2.14812858,
#         6.49738684,  1.65254511,  2.88034892,  3.37832415,  6.00132511,
#         6.43669266, 10.64152735, 10.29191113, 12.17603487,  3.33919367,
#         6.60875971,  2.27441008,  8.97553401,  1.79918021,  2.77800395,
#         8.62114498,  5.75110088,  2.80695495,  6.92521636,  6.91519808,
#         3.25413785,  6.80143028,  2.33585631, 13.1069586 ,  2.47690683,
#         3.03746794,  3.24028395,  3.24262044,  7.27737251,  2.33056015,
#         2.02412447,  3.04335298,  2.36859359,  2.72931536,  2.5652431 ,
#         4.17826288,  6.2849478 ,  2.28526984,  3.33304875,  2.37970114,
#         2.02580796,  3.57999888,  2.30951892,  3.94862839,  4.07766902,
# ...

# %% [markdown]
# ## comparing from original

# %%
Orginal = np.array(Y_test)
data1 = pd.DataFrame({'predicted': prdt,'original':Orginal})
data1
# Out:
#      predicted  original
# 0     6.972819  6.299605
# 1     2.999815  5.313293
# 2     2.365994  2.466212
# 3     3.014714  3.011070
# 4     4.557580  3.914868
# ..         ...       ...
# 222   2.120733  1.000000
# 223   2.458163  1.709976
# 224   8.535649  7.989570
# 225   2.282125  1.817121
# 226   2.562468  2.189760
#
# [227 rows x 2 columns]

# %% [markdown]
# hence we can see that our model approximately predicted most of the values

# %% [markdown]
# ### Seperating features and target variable(primary_fuel)

# %%
X= df.drop(['primary_fuel','country','country_long'], axis=1)
Y=df.primary_fuel

# %% [markdown]
# ### Scaling using Standard Scalar

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
X = pd.DataFrame(SS.fit_transform(X), columns = X.columns)
X
# Out:
#          name  gppd_idnr  capacity_mw  latitude  longitude  other_fuel1  \
# 0   -1.730142   0.779137    -1.126096  1.149805  -0.892687     0.054303
# 1   -1.726323   0.252074    -0.132660  0.587311  -0.593158     0.054303
# 2   -1.722504   1.527719    -0.503206  0.116179  -1.760007     0.054303
# 3   -1.718684  -1.730142     0.025977  0.439989   2.808168     0.054303
# 4   -1.714865  -1.726323     2.174090  0.125479   1.047925     0.054303
# ..        ...        ...          ...       ...        ...          ...
# 902  1.714865   0.145133     2.031075 -0.806975  -0.002532     0.054303
# 903  1.718684   1.409321    -1.100127 -1.366853   0.168603     0.054303
# 904  1.722504   1.672853    -0.641727 -0.974707  -0.382577     0.054303
# 905  1.726323   0.328460    -0.224749  0.518793  -0.781270     0.054303
# 906  1.730142   1.615563    -0.763130 -1.853834   0.022940     0.054303
#
#      commissioning_year     owner    source       url  geolocation_source  \
# ...

# %% [markdown]
# ### Checking for VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif['Features'] = X.columns
vif
# Out:
#     VIF values                Features
# 0     1.628822                    name
# 1     5.605361               gppd_idnr
# 2     2.247135             capacity_mw
# 3     1.118122                latitude
# 4     1.257127               longitude
# 5     1.034834             other_fuel1
# 6     1.952361      commissioning_year
# 7     3.819860                   owner
# 8     3.130752                  source
# 9     2.081724                     url
# 10    2.032389      geolocation_source
# 11    4.546401     generation_gwh_2014
# 12    8.267661     generation_gwh_2015
# 13   12.302341     generation_gwh_2016
# 14   10.319476     generation_gwh_2017
# 15   11.297556     generation_gwh_2018
# 16         NaN  generation_data_source

# %% [markdown]
# here we can see that some features have high VIF so we will remove some features and solve the problem of multicollinearity

# %%
X = X.drop(['generation_gwh_2016'], axis = 1)

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif['Features'] = X.columns
vif
# Out:
#     VIF values                Features
# 0     1.628628                    name
# 1     5.599361               gppd_idnr
# 2     2.247061             capacity_mw
# 3     1.115234                latitude
# 4     1.244964               longitude
# 5     1.033348             other_fuel1
# 6     1.930997      commissioning_year
# 7     3.819458                   owner
# 8     3.130216                  source
# 9     2.080955                     url
# 10    2.032044      geolocation_source
# 11    4.521545     generation_gwh_2014
# 12    5.589364     generation_gwh_2015
# 13    9.625063     generation_gwh_2017
# 14   10.516877     generation_gwh_2018
# 15         NaN  generation_data_source

# %%
X = X.drop(['generation_gwh_2018'], axis = 1)

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif['Features'] = X.columns
vif
# Out:
#     VIF values                Features
# 0     1.627630                    name
# 1     5.597253               gppd_idnr
# 2     2.241380             capacity_mw
# 3     1.115227                latitude
# 4     1.244718               longitude
# 5     1.018597             other_fuel1
# 6     1.930955      commissioning_year
# 7     3.814676                   owner
# 8     3.129988                  source
# 9     2.077890                     url
# 10    2.029661      geolocation_source
# 11    4.467076     generation_gwh_2014
# 12    5.422165     generation_gwh_2015
# 13    3.339315     generation_gwh_2017
# 14         NaN  generation_data_source

# %% [markdown]
# here we removed the problem of multicollinearity

# %% [markdown]
# ## Creating train test Split

# %%
from sklearn.model_selection import train_test_split
for i in range(1,100):
    X_train,X_test,Y_train,Y_test =train_test_split (X,Y, test_size = 0.25 , random_state = i)

# %% [markdown]
# #### importing necessary libraries for models

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report 
from sklearn.svm import SVC
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #### Models

# %% [markdown]
# #### AdaBoostClassifier

# %%
abc = AdaBoostClassifier()
abc.fit(X_train, Y_train)
y_pred = abc.predict(X_train)
accuracy = accuracy_score( Y_train,y_pred ) # checking train data 
print("accuracy score of trained data--->",accuracy)
# Out:
# accuracy score of trained data---> 0.5485294117647059

# %%
y_pred_testABC  = abc.predict(X_test)
accuracy = accuracy_score( Y_test,y_pred_testABC ) # checking test data 
print('accuracy score of test data-->',accuracy)
# Out:
# accuracy score of test data--> 0.5859030837004405

# %%
print(  '.                      classification report                        .\n',
      classification_report(Y_test,y_pred_testABC))
# Out:
# .                      classification report                        .
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.52      0.26      0.35        61
#            2       0.00      0.00      0.00        17
#            3       0.52      1.00      0.68        70
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         8
#            6       1.00      0.93      0.97        30
#            7       1.00      0.61      0.76        31
#
#     accuracy                           0.59       227
#    macro avg       0.38      0.35      0.34       227
# weighted avg       0.57      0.59      0.54       227

# %% [markdown]
# #### RandomForestClassifier

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, Y_train)
y_pred = rfc.predict(X_train)
accuracy = accuracy_score( Y_train,y_pred ) # checking train data 
print("accuracy score of trained data--->",accuracy)
# Out:
# accuracy score of trained data---> 1.0

# %%
y_pred_testRFC  = rfc.predict(X_test)
accuracy = accuracy_score( Y_test,y_pred_testRFC ) # checking test data 
print('accuracy score oftest data-->',accuracy)
# Out:
# accuracy score oftest data--> 0.8325991189427313

# %%
print(  '.                      classification report                        .\n',
      classification_report(Y_test,y_pred_testRFC))
# Out:
# .                      classification report                        .
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        10
#            1       0.77      0.87      0.82        61
#            2       0.44      0.41      0.42        17
#            3       0.87      0.83      0.85        70
#            5       0.50      0.25      0.33         8
#            6       1.00      1.00      1.00        30
#            7       1.00      1.00      1.00        31
#
#     accuracy                           0.83       227
#    macro avg       0.77      0.74      0.75       227
# weighted avg       0.83      0.83      0.83       227

# %% [markdown]
# #### LogisticRegression

# %%
log_R =LogisticRegression()
log_R.fit(X_train, Y_train)
y_pred = log_R.predict(X_train)
accuracy = accuracy_score( Y_train,y_pred ) # checking train data 
print("accuracy score of trained data--->",accuracy)
# Out:
# accuracy score of trained data---> 0.7970588235294118

# %%
y_pred_testLR  = log_R.predict(X_test)
accuracy = accuracy_score( Y_test,y_pred_testLR ) # checking test data 
print('accuracy score oftest data-->',accuracy)
# Out:
# accuracy score oftest data--> 0.7400881057268722

# %%
print(  '.                      classification report                        .\n',
      classification_report(Y_test,y_pred_testLR))
# Out:
# .                      classification report                        .
#                precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.62      0.79      0.70        61
#            2       0.33      0.12      0.17        17
#            3       0.72      0.74      0.73        70
#            5       0.00      0.00      0.00         8
#            6       1.00      0.90      0.95        30
#            7       0.94      1.00      0.97        31
#
#     accuracy                           0.74       227
#    macro avg       0.61      0.62      0.61       227
# weighted avg       0.71      0.74      0.72       227

# %% [markdown]
# #### SVC

# %%
SVM = SVC()
SVM.fit(X_train, Y_train)
y_pred = SVM.predict(X_train)
accuracy = accuracy_score( Y_train,y_pred ) # checking train data 
print("accuracy score of trained data--->",accuracy)
# Out:
# accuracy score of trained data---> 0.8323529411764706

# %%
y_pred_testSVM  = SVM.predict(X_test)
accuracy = accuracy_score( Y_test,y_pred_testSVM ) # checking test data 
print('accuracy score oftest data-->',accuracy)
# Out:
# accuracy score oftest data--> 0.775330396475771

# %%
print(  '.                      classification report                        .\n',
      classification_report(Y_test,y_pred_testSVM))
# Out:
# .                      classification report                        .
#                precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.71      0.82      0.76        61
#            2       0.25      0.06      0.10        17
#            3       0.74      0.84      0.79        70
#            5       0.00      0.00      0.00         8
#            6       1.00      0.90      0.95        30
#            7       0.91      1.00      0.95        31
#
#     accuracy                           0.78       227
#    macro avg       0.61      0.63      0.61       227
# weighted avg       0.72      0.78      0.74       227

# %% [markdown]
# #### GradientBoostingClassifier

# %%
GBC = GradientBoostingClassifier()
GBC.fit(X_train, Y_train)
y_pred = GBC.predict(X_train)
accuracy = accuracy_score( Y_train,y_pred ) # checking train data 
print("accuracy score of trained data--->",accuracy)
# Out:
# accuracy score of trained data---> 1.0

# %%
y_pred_testGBC  = GBC.predict(X_test)
accuracy = accuracy_score( Y_test,y_pred_testGBC ) # checking test data 
print('accuracy score oftest data-->',accuracy)
# Out:
# accuracy score oftest data--> 0.8634361233480177

# %%
print(  '.                      classification report                        .\n',
      classification_report(Y_test,y_pred_testGBC))
# Out:
# .                      classification report                        .
#                precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82        10
#            1       0.84      0.92      0.88        61
#            2       0.50      0.47      0.48        17
#            3       0.87      0.87      0.87        70
#            5       1.00      0.25      0.40         8
#            6       1.00      0.97      0.98        30
#            7       1.00      1.00      1.00        31
#
#     accuracy                           0.86       227
#    macro avg       0.85      0.77      0.78       227
# weighted avg       0.87      0.86      0.86       227

# %% [markdown]
# #### KNN

# %%
KNN =KNeighborsClassifier()
KNN.fit(X_train, Y_train)
y_pred = KNN.predict(X_train)
accuracy = accuracy_score( Y_train,y_pred ) # checking train data 
print("accuracy score of trained data--->",accuracy)
# Out:
# accuracy score of trained data---> 0.8514705882352941

# %%
y_pred_testKNN  = KNN.predict(X_test)
accuracy = accuracy_score( Y_test,y_pred_testKNN ) # checking test data 
print('accuracy score oftest data-->',accuracy)
# Out:
# accuracy score oftest data--> 0.7533039647577092

# %%
print(  '.                      classification report                        .\n',
      classification_report(Y_test,y_pred_testKNN))
# Out:
# .                      classification report                        .
#                precision    recall  f1-score   support
#
#            0       0.53      0.80      0.64        10
#            1       0.69      0.82      0.75        61
#            2       0.31      0.29      0.30        17
#            3       0.78      0.71      0.75        70
#            5       0.00      0.00      0.00         8
#            6       1.00      0.90      0.95        30
#            7       0.94      1.00      0.97        31
#
#     accuracy                           0.75       227
#    macro avg       0.61      0.65      0.62       227
# weighted avg       0.73      0.75      0.74       227

# %% [markdown]
# we will check which model to choose by seeing cross validation score

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cscore1 = cross_val_score(rfc,X,Y)
print('Cscore for RandomForest Classifier-> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between accuracy and cross validation score is',accuracy_score(Y_test,y_pred_testRFC)-cscore1.mean())
# Out:
# Cscore for RandomForest Classifier->  [0.83516484 0.86813187 0.8839779  0.84530387 0.85635359]
# mean of cscore->  0.8577864124825452
# difference between accuracy and cross validation score is -0.02518729353981386

# %%
cscore2 = cross_val_score(KNN,X,Y)
print('Cscore for Kneighbours Classifier ',cscore2)
print('mean of cscore-> ',cscore2.mean())
print('difference between accuracy and cross validation score is',accuracy_score(Y_test,y_pred_testKNN)-cscore2.mean())
# Out:
# Cscore for Kneighbours Classifier  [0.76923077 0.78021978 0.80662983 0.78453039 0.77348066]
# mean of cscore->  0.7828182866856901
# difference between accuracy and cross validation score is -0.02951432192798087

# %%
cscore3 = cross_val_score(abc,X,Y)
print('Cscore for AdaBoost Classifier-> ',cscore3)
print('mean of cscore-> ',cscore3.mean())
print('difference between accuracy and cross validation score is',accuracy_score(Y_test,y_pred_testABC)-cscore3.mean())
# Out:
# Cscore for AdaBoost Classifier->  [0.3956044  0.64835165 0.50276243 0.65745856 0.70718232]
# mean of cscore->  0.5822718717746342
# difference between accuracy and cross validation score is 0.003631211925806288

# %%
cscore4 = cross_val_score(GBC,X,Y)
print('Cscore for Gradient Boost Classifier -> ',cscore4)
print('mean of cscore-> ',cscore4.mean())
print('difference between accuracy and cross validation score is',accuracy_score(Y_test,y_pred_testGBC)-cscore4.mean())
# Out:
# Cscore for Gradient Boost Classifier ->  [0.82417582 0.87912088 0.87845304 0.83425414 0.85635359]
# mean of cscore->  0.8544714953554731
# difference between accuracy and cross validation score is 0.008964627992544605

# %%
cscore5 = cross_val_score(SVM,X,Y)
print('Cscore for SUpport Vector Machine-> ',cscore5)
print('mean of cscore-> ',cscore5.mean())
print('difference between accuracy and cross validation score is',accuracy_score(Y_test,y_pred_testSVM)-cscore5.mean())
# Out:
# Cscore for SUpport Vector Machine->  [0.8021978  0.80769231 0.79005525 0.79558011 0.80662983]
# mean of cscore->  0.8004310606520552
# difference between accuracy and cross validation score is -0.025100664176284204

# %%
cscore6 = cross_val_score(log_R,X,Y)
print('Cscore for Logistic Regression',cscore6)
print('mean of cscore-> ',cscore6.mean())
print('difference between accuracy and cross validation score is',accuracy_score(Y_test,y_pred_testLR)-cscore6.mean())
# Out:
# Cscore for Logistic Regression [0.8021978  0.79120879 0.79005525 0.78453039 0.79005525]
# mean of cscore->  0.7916094954768987
# difference between accuracy and cross validation score is -0.051521389750026514

# %% [markdown]
# here based on cscore value we will use gradient boost classifier

# %% [markdown]
# ## Hyper parameter tuning

# %%
GBC.get_params().keys()
# Out:
# dict_keys(['ccp_alpha', 'criterion', 'init', 'learning_rate', 'loss', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_iter_no_change', 'random_state', 'subsample', 'tol', 'validation_fraction', 'verbose', 'warm_start'])

# %%
parameters = {
    'loss': ['deviance', 'exponential'],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [50, 100, 150],
    'subsample': [0.8, 0.9, 1.0],
    'criterion': ['friedman_mse', 'squared_error']
}

# %%
GSC = GridSearchCV(GradientBoostingClassifier(),parameters,cv= 5)

# %%
GSC.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'learning_rate': [0.01, 0.1, 0.2],
#                          'loss': ['deviance', 'exponential'],
#                          'n_estimators': [50, 100, 150],
#                          'subsample': [0.8, 0.9, 1.0]})

# %%
GSC.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.2,
#  'loss': 'deviance',
#  'n_estimators': 100,
#  'subsample': 0.8}

# %%
GBC_final = GradientBoostingClassifier(criterion= 'friedman_mse',learning_rate= 0.2, n_estimators = 100, loss = 'deviance' , subsample=0.8 )
GBC_final.fit(X_train, Y_train)
y_pred = GBC_final.predict(X_train)
accuracy = accuracy_score( Y_train,y_pred ) # checking train data 
print("accuracy score of trained data--->",accuracy)
# Out:
# accuracy score of trained data---> 1.0

# %%
y_pred_testGBC  = GBC_final.predict(X_test)
accuracy = accuracy_score( Y_test,y_pred_testGBC ) # checking test data 
print('accuracy score of test data-->',accuracy)
# Out:
# accuracy score of test data--> 0.8414096916299559

# %% [markdown]
# here we see thar after hyperparameter tuning we will get less that what we see before so we will further manipulate it

# %%
GBC_final = GradientBoostingClassifier(criterion= 'squared_error',learning_rate= 0.2, n_estimators = 150, loss = 'deviance' , subsample=0.9 )
GBC_final.fit(X_train, Y_train)
y_pred = GBC_final.predict(X_train)
accuracy = accuracy_score( Y_train,y_pred ) # checking train data 
print("accuracy score of trained data--->",accuracy)
# Out:
# accuracy score of trained data---> 1.0

# %%
y_pred_testGBC  = GBC_final.predict(X_test)
accuracy = accuracy_score( Y_test,y_pred_testGBC ) # checking test data 
print('accuracy score of test data-->',accuracy)
# Out:
# accuracy score of test data--> 0.8634361233480177

# %% [markdown]
# here we see we increse the score

# %% [markdown]
# ## Model Saving

# %%
import joblib
joblib.dump(GBC_final,'model for avocado (region)')
# Out:
# ['model for avocado (region)']

# %% [markdown]
# # Prediction

# %%
mymodel = joblib.load('model for avocado (region)')
prdt = mymodel.predict(X_test)
prdt
# Out:
# array([1, 7, 3, 7, 3, 7, 1, 1, 3, 5, 6, 3, 1, 1, 7, 3, 1, 7, 3, 6, 3, 6,
#        0, 2, 2, 1, 1, 3, 1, 7, 2, 3, 3, 3, 0, 1, 3, 0, 1, 3, 1, 3, 3, 1,
#        6, 1, 7, 6, 2, 6, 3, 1, 3, 3, 7, 1, 2, 6, 1, 6, 6, 0, 3, 3, 1, 1,
#        1, 1, 1, 3, 6, 3, 7, 1, 1, 3, 2, 7, 6, 1, 3, 1, 2, 0, 7, 7, 2, 1,
#        3, 3, 3, 3, 1, 0, 6, 7, 3, 7, 6, 2, 3, 3, 1, 0, 6, 3, 3, 6, 1, 1,
#        1, 3, 2, 1, 3, 1, 1, 1, 3, 2, 7, 1, 3, 3, 3, 1, 7, 3, 1, 3, 6, 1,
#        7, 3, 1, 7, 3, 2, 3, 3, 3, 6, 1, 3, 7, 3, 1, 7, 7, 1, 3, 7, 1, 1,
#        1, 1, 6, 6, 1, 7, 1, 2, 3, 1, 3, 7, 2, 1, 7, 1, 3, 3, 2, 3, 1, 1,
#        6, 3, 3, 1, 1, 0, 3, 3, 3, 7, 0, 3, 1, 3, 1, 0, 6, 1, 3, 3, 0, 6,
#        1, 3, 3, 6, 7, 1, 3, 6, 1, 1, 1, 1, 6, 6, 6, 7, 2, 3, 7, 3, 3, 7,
#        1, 1, 6, 6, 1, 3, 7])

# %% [markdown]
# ## comparing from original

# %%
Orginal = np.array(Y_test)
data1 = pd.DataFrame({'predicted': prdt,'original':Orginal})
data1
# Out:
#      predicted  original
# 0            1         1
# 1            7         7
# 2            3         3
# 3            7         7
# 4            3         3
# ..         ...       ...
# 222          6         6
# 223          6         6
# 224          1         3
# 225          3         3
# 226          7         7
#
# [227 rows x 2 columns]

# %% [markdown]
# here we can see that our model predict almost all the data
