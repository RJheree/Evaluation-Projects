# %% [markdown]
# ## Name- Ranjan Pratap Singh                                                      DS2307

# %% [markdown]
# # Baseball Case Study
# ## Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
# ### -- Input features-
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
#
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
#
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
#
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
#
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
#
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
#
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
#
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
#
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
#
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
#
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
#
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
#
# -- Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv(r"C:\Users\RANJAN\Downloads\evaluation phase 1\baseball.csv")

# %% [markdown]
# ### Exploratory Data Analysis(EDA)  ----->

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# #### Our dataset contain is of Baseball case study has 30 rows and 17 columns, and all the columns are described in project description W is our target variable and it is numerical so we will use regresson models to train, test predict the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# here we can see that our dataset contain two dtpyes i.e. int and float and there are no null values in our data set .

# %%
#  checking the values counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64
#
#
# 1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: H, dtype: int64
#
#
# 272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: 2B, dtype: int64
#
#
# 27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: 3B, dtype: int64
#
#
# 136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: HR, dtype: int64
#
#
# 478    2
# 383    1
# 461    1
# 426    1
# 490    1
# 457    1
# 563    1
# 387    1
# 471    1
# 375    1
# 539    1
# 488    1
# 496    1
# 412    1
# 567    1
# 506    1
# 439    1
# 475    1
# 435    1
# 486    1
# 503    1
# 436    1
# 418    1
# 554    1
# 570    1
# 455    1
# 404    1
# 533    1
# 388    1
# Name: BB, dtype: int64
#
#
# 1150    2
# 973     1
# 1267    1
# 1327    1
# 1312    1
# 1159    1
# 1258    1
# 1274    1
# 1107    1
# 1344    1
# 1290    1
# 1255    1
# 1299    1
# 1518    1
# 1322    1
# 1119    1
# 1264    1
# 1336    1
# 1392    1
# 1233    1
# 1148    1
# 1310    1
# 1331    1
# 1227    1
# 1151    1
# 1259    1
# 1231    1
# 1157    1
# 1283    1
# Name: SO, dtype: int64
#
#
# 69     3
# 88     2
# 78     1
# 82     1
# 132    1
# 93     1
# 59     1
# 112    1
# 57     1
# 51     1
# 134    1
# 84     1
# 95     1
# 98     1
# 104    1
# 70     1
# 52     1
# 121    1
# 101    1
# 71     1
# 87     1
# 44     1
# 63     1
# 83     1
# 68     1
# 86     1
# 97     1
# Name: SB, dtype: int64
#
#
# 641    1
# 700    1
# 731    1
# 713    1
# 627    1
# 595    1
# 809    1
# 760    1
# 678    1
# 635    1
# 613    1
# 754    1
# 737    1
# 608    1
# 596    1
# 525    1
# 729    1
# 726    1
# 675    1
# 618    1
# 733    1
# 753    1
# 642    1
# 693    1
# 698    1
# 670    1
# 803    1
# 701    1
# 640    1
# 844    1
# Name: RA, dtype: int64
#
#
# 601    1
# 653    1
# 655    1
# 659    1
# 597    1
# 553    1
# 749    1
# 698    1
# 638    1
# 577    1
# 557    1
# 700    1
# 682    1
# 546    1
# 532    1
# 478    1
# 664    1
# 677    1
# 630    1
# 572    1
# 680    1
# 694    1
# 604    1
# 646    1
# 652    1
# 609    1
# 746    1
# 643    1
# 584    1
# 799    1
# Name: ER, dtype: int64
#
#
# 3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: ERA, dtype: int64
#
#
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64
#
#
# 12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: SHO, dtype: int64
#
#
# 35    4
# 41    3
# 45    3
# 44    2
# 48    2
# 40    2
# 56    1
# 28    1
# 47    1
# 50    1
# 54    1
# 62    1
# 39    1
# 46    1
# 60    1
# 43    1
# 34    1
# 37    1
# 38    1
# 36    1
# Name: SV, dtype: int64
#
#
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: E, dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# In description we have count,mean, standard deviation(STD) , minimum(min), 25%,50%(median),75%,maximum(max)
#
# as we can see that there is no negative value so our description of dataset is valid
#
# number of observations are same in all columns so there is no missing values
#
# if we compare mean with median i.e. 50% we can see  all the data have almost same so  the data is normally distributed
#
# if we see for outliers we can observe that some coulmn may contain outliers that we will check  later in this model

# %% [markdown]
# ### Data Visualization --->

# %%
df1 = df.drop(['CG','SHO','SV'],axis=1)

# %%
plt.figure(figsize=(30, 30), facecolor="lightgrey")
plotnumber = 1

for column in df1:  
    if plotnumber <= 14:
        ax = plt.subplot(5, 3, plotnumber)
        sns.histplot(x=df[column], data=df1, kde=True, color='red')
        plt.xlabel(column, fontsize = 20)
    plotnumber += 1

plt.show()

# %% [markdown]
# here in the univariate graphs we can see that all the plot except H and E are normally distributed and they are positevely skewed we will further solve this problem of skewness.

# %%
sns.countplot(x='CG' , data = df )
plt.xlabel('CG',color = 'r')
plt.grid(axis ='y')
plt.show()
df['CG'].value_counts()
# Out:
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64

# %% [markdown]
# here we can see that CG = 1 has most occoured

# %%
sns.countplot(x='SHO' , data = df )
plt.xlabel('SHO',color = 'r')
plt.grid(axis ='y')
plt.show()
df['SHO'].value_counts()
# Out:
# 12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: SHO, dtype: int64

# %% [markdown]
# here we can see that SHO = 10,12 have most occoured

# %%
sns.countplot(x='SV' , data = df )
plt.xlabel('SV',color = 'r')
plt.grid(axis ='y')
plt.show()
df['SV'].value_counts()
# Out:
# 35    4
# 41    3
# 45    3
# 44    2
# 48    2
# 40    2
# 56    1
# 28    1
# 47    1
# 50    1
# 54    1
# 62    1
# 39    1
# 46    1
# 60    1
# 43    1
# 34    1
# 37    1
# 38    1
# 36    1
# Name: SV, dtype: int64

# %% [markdown]
# here we can see that SV = 35,41,45 has most occoured

# %% [markdown]
# - bivariate analysis

# %%
dfz = df1.drop(['W'],axis=1)

# %%
plt.figure(figsize=(30, 30), facecolor="lightblue")
plotnumber = 1
for column in dfz.columns:  
    if plotnumber <= 14:
        plt.subplot(5, 3, plotnumber)
        sns.regplot(x=dfz[column], y=df['W'], data=dfz)
        plt.xlabel(column, fontsize=20)
        plt.ylabel('W',fontsize = 20)
    plotnumber += 1
plt.show()

# %% [markdown]
# here we can see that W has positive realtionship with R ,2B,BB,HR and negative relationship with RA,ER.ERA

# %%
sns.barplot(x='CG', y= 'W', data= df )
plt.show()

# %% [markdown]
# we can not find any significance relation between CG and W

# %%
sns.barplot(x='SHO', y= 'W', data= df )
plt.show()

# %% [markdown]
# we can not find any significance relation between SHO and W

# %%
sns.barplot(x='SV', y= 'W', data= df )
plt.show()

# %% [markdown]
# we can not find any significance relation between SV and W

# %% [markdown]
# ### -- Checking for Outliers

# %%
plt.figure(figsize=(30, 30), facecolor="pink")
plotnumber = 1

for column in df1:  
    if plotnumber <= 14:
        ax = plt.subplot(5, 3, plotnumber)
        sns.boxplot( y = df1[column] , palette = 'Set2_r')
        plt.ylabel(column)
    plotnumber += 1

plt.show()

# %% [markdown]
# here we can see that there are outliers present in the data in the E,ERa we will try to rsolve it

# %%
from scipy.stats import zscore
z = np.abs(zscore(df1))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# 12  0.392433  0.471376  1.432772  1.291077  1.783647  1.002270  0.395247
# 13  0.483244  0.557920  0.400291  0.436688  0.715707  0.904962  1.098383
# 14  1.261625  0.099814  1.208570  0.026106  0.127403  1.430424  0.563574
# 15  1.851896  0.713699  0.465723  0.312089  0.745685  0.749270  0.851220
# 16  1.657301  0.151740  1.656011  1.040693  0.970514  0.418423  0.755338
# 17  1.560004  0.013270  0.364688  1.113079  0.153633  0.126500  0.235444
# 18  1.261625  0.575229  0.523457  0.454487  0.041219  0.262731  0.595534
# 19  1.650815  0.834861  0.789997  0.383288  0.996744  0.418423  0.107601
# 20  0.878921  0.090583  0.154920  0.935081  1.139136  1.391501  0.427208
# 21  0.197838  0.255593  1.274002  0.721484  0.547085  1.780732  0.427208
# 22  0.969732  1.302198  0.768828  0.293103  2.177099  0.846578  1.394552
# 23  1.358922  1.994550  1.389471  0.757084  1.333988  1.294193  2.033766
# 24  1.748112  1.077184  0.183787  0.525687  0.153633  0.554654  1.074945
# 25  1.073516  0.367523  1.894646  1.024080  0.659500  0.515731  0.746815
# 26  0.295136  0.134432  0.703396  1.467888  0.745685  0.749270  0.883181
# 27  0.191352  0.549843  1.915815  1.610286  0.801892  1.625040  0.307888
# 28  0.677839  0.661773  0.855429  1.415675  0.828122  0.457346  0.499652
# 29  1.261625  0.844092  0.804431  1.343289  0.041219  1.722347  0.714854
#
#           BB        SO        SB        RA        ER       ERA         E
# 0   1.534902  2.697630  0.913883  0.666234  0.505110  0.506955  0.461470
# 1   0.536592  0.154878  0.601826  0.165971  0.248930  0.254598  0.607197
# 2   1.139144  0.893982  0.111449  0.680339  0.751623  0.641347  1.117242
# 3   1.160536  0.168602  0.690985  0.180076  0.103922  0.053010  0.485758
# 4   0.251360  0.105866  0.022290  1.618803  1.597501  1.531318  0.607197
# 5   1.798742  0.952796  0.200609  0.257184  0.389104  0.350165  0.461470
# 6   1.513510  0.207812  0.913883  0.137760  0.234429  0.165003  0.097152
# 7   0.910958  0.811641  1.760897  0.067235  0.147424  0.209800  1.262970
# 8   0.590073  0.605790  0.156029  0.652129  0.461608  0.484557  0.048576
# 9   0.158660  0.982204  0.557246  0.913544  0.843461  0.792164  0.194303
# 10  0.604334  0.148997  0.780144  0.631441  0.640451  0.635374  1.797303
# 11  0.301276  1.409590  1.671738  0.990653  0.925632  0.865333  0.680061
# 12  0.607900  0.962599  1.404260  0.186658  0.084588  0.036584  0.097152
# 13  0.158660  0.860654  0.646405  0.532705  0.596948  0.456185  0.024288
# 14  0.105179  1.266474  0.245188  0.575021  0.408438  0.411388  2.307348
# 15  0.657815  0.184286  0.646405  2.302433  2.288705  2.276445  0.121439
# 16  0.144398  0.723420  0.646405  1.300966  1.505663  1.671683  2.015894
# 17  1.745261  2.644696  0.512666  1.131704  1.302652  1.335704  1.214394
# 18  1.017920  0.497964  0.022290  0.687862  0.669452  0.724968  1.578712
# 19  0.479546  0.066657  2.251273  0.927650  0.930466  0.836961  0.315742
# 20  0.336930  0.409742  1.448839  1.061179  1.143144  1.178913  0.461470
# 21  1.246105  0.939073  1.181361  0.750865  0.853129  0.753340  0.315742
# 22  1.677518  0.962599  1.270521  0.144343  0.031418  0.142604  1.262970
# 23  0.033871  1.384104  0.646405  1.012281  0.901464  1.016150  0.315742
# 24  1.463595  0.252903  0.200609  1.703434  1.641004  1.643311  1.651576
# 25  1.673953  0.096064  1.092202  1.315071  1.201147  1.156515  1.408697
# 26  0.215706  0.874377  0.423507  0.863706  0.563113  0.529354  1.190106
# 27  0.372584  0.625395  2.162114  0.349338  0.335934  0.187402  0.607197
# 28  0.768343  0.772432  0.066870  0.603231  0.277931  0.299395  0.170015
# 29  1.445768  0.341125  0.601826  2.197114  2.366042  2.427263  0.048576

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df2= df[(z<3).all(axis=1)]

# %%
print('percentage of dataloss',((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# percentage of dataloss 3.3333333333333335

# %%
df = df2

# %% [markdown]
# here we stillhave outliers left but we choose to continue as we dont have big data so we cant not remove more outliers

# %%
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ### -- Checking for Skewness

# %%
plt.figure(figsize=(30, 30), facecolor="pink")
plotnumber = 1

for i in df1:  
    if plotnumber <= 14:
        ax = plt.subplot(5, 3, plotnumber)
        sns.distplot(df1[i])
        plt.xlabel(i, fontsize=10)
    plotnumber += 1

plt.show()

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# here we can see that data is not skewed

# %% [markdown]
# ### checking for correlation

# %%
correlation = df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(correlation , annot = True)
plt.show()

# %% [markdown]
# here in correlation we can see that RA ER ERA has high correaltion with SV, SHO so there can be a probel of multicollinearity we will further see in this model

# %% [markdown]
# ### Seperating features and target variable

# %%
X= df.drop(['W'], axis=1)
Y=df.W

# %% [markdown]
# ### Scaling using Standard Scalar

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
X = pd.DataFrame(SS.fit_transform(X), columns = X.columns)
X
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# 12 -0.566355  0.390081 -0.396062 -0.682763 -0.969865  1.262607  0.230197
# 13  0.286272  1.184926  0.074223  0.201171  1.406988 -0.525197  0.174411
# 14 -0.768292 -0.461539 -0.269447  0.849390  0.713739 -0.834625  0.750867
# 15  0.353585  1.624929  1.105231  1.085106 -0.474688 -0.731482 -0.085923
# 16  0.174084 -0.362183 -1.083401 -0.093474 -0.177581  0.334324  1.885182
# 17 -0.588792 -0.518313 -0.414150  0.024384  0.218561 -0.559578 -0.997094
# 18 -0.925355  0.773310 -0.341798 -0.977408 -0.474688  0.196801  0.564913
# 19  0.039459  0.148789 -0.902522  1.261893 -1.465043  0.540609  0.416151
# 20  0.488210 -1.256383 -0.685468 -0.505976 -1.861185  0.540609  1.364512
# 21 -1.531169 -0.759605  0.345541 -2.214917  0.812774 -1.419099 -1.685122
# 22 -2.428670 -1.369933 -0.721643 -1.330982 -1.366007 -2.106716  0.100030
# 23 -1.239481  0.177176 -0.486501 -0.093474  0.515668 -1.075291 -1.461978
# 24 -0.319542 -1.866711 -0.992961 -0.623834 -0.573723  0.884418  1.810800
# 25  0.331147  0.688148  1.539340  0.849390  0.713739 -0.869006 -0.160305
# 26  0.869648  1.880415  1.684043  0.908319  1.605059 -0.250150  0.453341
# 27 -0.700980 -0.844767 -1.390895 -0.800621  0.416632 -0.456435 -0.736760
# 28  1.251086  0.787503  1.412725  0.024384  1.704094  0.850037 -1.443382
#
#           SO        SB        RA        ER       ERA        CG       SHO  \
# 0  -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.501486 -0.813262
# 1   0.121896 -0.585315  0.154638  0.232161  0.238952 -0.501486  0.159299
# 2  -0.925866  0.116458 -0.678397 -0.754153 -0.643801  2.854612 -0.326982
# 3  -0.201246 -0.673037  0.168522  0.089217  0.040333  1.363013 -0.570122
# 4   0.072935 -0.015124  1.584683  1.561540  1.496876  1.363013  0.159299
# 5  -0.240414 -0.892341  0.126870  0.217866  0.150677 -0.128586 -1.785822
# 6   0.777970 -1.725697  0.057451  0.132100  0.194815 -1.247285 -0.326982
# 7   0.572335  0.160319 -0.650630 -0.468265 -0.489319 -0.874386  0.159299
# 8  -1.013995 -0.541454  0.890486  0.818231  0.768604 -0.128586 -0.326982
# 9  -0.181661  0.774370  0.612808  0.618110  0.614123  0.617213 -0.570122
# 10  1.375292  1.651587 -0.983844 -0.925686 -0.864490  0.617213  0.402439
# 11 -0.994411 -1.374810 -0.192460 -0.096610 -0.047943 -0.501486  0.159299
# 12  0.826931 -0.629176  0.515620  0.575226  0.437572  0.990113  0.159299
# 13 -1.297968 -0.234429  0.557272  0.389399  0.393434  0.617213  0.888719
# 14  0.151272 -0.629176 -2.275049 -2.269360 -2.254827 -0.874386  0.888719
# 15  0.689841  0.642788 -1.289290 -1.497462 -1.658968 -1.247285  0.402439
# 16  2.609104  0.511205 -1.122683 -1.297340 -1.327935  0.990113  2.347560
# 17  0.464621  0.028736  0.668344  0.646698  0.702398 -0.874386 -1.056402
# 18  0.033766  2.221778  0.904370  0.903998  0.812742 -0.501486 -0.813262
# 19  0.376492 -1.418671 -1.053264 -1.140102 -1.173453 -0.874386  0.645579
# 20  0.905268 -1.155506 -0.747817 -0.854214 -0.754146  0.244314  0.402439
# 21 -0.994411  1.256840 -0.150808  0.017745  0.128608 -1.247285  0.159299
# 22 -1.415474 -0.629176  0.987674  0.875409  0.989293 -0.128586 -0.326982
# 23  0.219817  0.204180  1.667986  1.604423  1.607220 -0.874386 -1.056402
# 24  0.063143 -1.067784 -1.303174 -1.197279 -1.151385  0.990113  2.347560
# 25 -0.906281  0.423484 -0.858889 -0.568326 -0.533457  1.363013  1.618139
# 26  0.591919  2.134056  0.335129  0.317927  0.172746 -0.874386  0.159299
# 27  0.738802 -0.058985  0.585040  0.260750  0.283090 -0.874386 -1.299542
# 28  0.307947  0.598927  2.153924  2.319144  2.379630  0.244314 -1.785822
#
#           SV         E
# 0   1.643157 -0.471091
# 1   0.211006 -0.614898
# 2  -0.700362 -1.118222
# 3  -0.830557  0.463653
# 4  -1.090948 -0.614898
# 5   0.601593 -0.111574
# 6  -0.049384 -1.262029
# 7   2.163939  0.032233
# 8  -0.439971  0.176039
# 9   0.211006  1.757915
# 10 -0.570166 -0.686802
# 11  0.341202 -0.111574
# 12  0.211006 -0.039671
# 13 -2.002317  2.261239
# 14  2.424329  0.104136
# 15  1.382766  1.973625
# 16  0.601593  1.182687
# 17 -0.439971  1.542205
# 18 -1.090948 -0.327285
# 19  0.861984 -0.471091
# 20 -0.309775 -0.327285
# 21 -1.090948 -1.262029
# 22  0.080811 -0.327285
# 23 -1.090948  1.614108
# 24  0.471397 -1.405836
# 25 -0.309775 -1.190126
# 26  0.080811 -0.614898
# 27 -0.309775 -0.183478
# 28 -0.960753  0.032233

# %% [markdown]
# ### checking for Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif['Features'] = X.columns
vif
# Out:
#      VIF values Features
# 0      7.229564        R
# 1     18.333377       AB
# 2     10.558458        H
# 3      3.743423       2B
# 4      3.278636       3B
# 5      8.426403       HR
# 6      3.431971       BB
# 7      2.720640       SO
# 8      2.110804       SB
# 9    197.315706       RA
# 10  1825.871631       ER
# 11  1438.816208      ERA
# 12     3.074115       CG
# 13     3.673885      SHO
# 14     6.236487       SV
# 15     2.180914        E

# %%
X = X.drop(['ER'], axis = 1)

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif['Features'] = X.columns
vif
# Out:
#     VIF values Features
# 0     6.789990        R
# 1     7.689961       AB
# 2     9.703669        H
# 3     3.423326       2B
# 4     3.268301       3B
# 5     7.683683       HR
# 6     3.430050       BB
# 7     2.713114       SO
# 8     1.907595       SB
# 9   144.425392       RA
# 10  139.967064      ERA
# 11    2.649316       CG
# 12    3.498198      SHO
# 13    3.174949       SV
# 14    2.092189        E

# %%
X = X.drop(['RA'], axis = 1)

# %%
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif['Features'] = X.columns
vif
# Out:
#     VIF values Features
# 0     6.787762        R
# 1     4.981743       AB
# 2     8.569581        H
# 3     3.416116       2B
# 4     3.239565       3B
# 5     6.590925       HR
# 6     3.081560       BB
# 7     2.106522       SO
# 8     1.842528       SB
# 9     4.931066      ERA
# 10    2.649063       CG
# 11    3.231029      SHO
# 12    3.075865       SV
# 13    2.039641        E

# %% [markdown]
# here we removed the features who have high VIF and now multicollinearity problem has been solved

# %% [markdown]
# ## Creating train test Split

# %%
from sklearn.model_selection import train_test_split
for i in range(1,100):
    X_train,X_test,Y_train,Y_test =train_test_split (X,Y, test_size = 0.25 , random_state = i)

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor 
LR = LinearRegression()
RIG= Ridge()
SVM=SVR()
LS= Lasso()
RFR=RandomForestRegressor()
DTR = DecisionTreeRegressor()
abr = AdaBoostRegressor()
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Models

# %% [markdown]
# #### Lasso

# %%
LS.fit(X_train, Y_train)
y_pred = LS.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.8417963314373059

# %%
y_pred_testLS  = LS.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testLS ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.7893058812420911

# %%
mae = mean_absolute_error(Y_test, y_pred_testLS)
mse = mean_squared_error(Y_test, y_pred_testLS)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 4.305823659103268
# Mean Squared Error -->: 28.450931016270186
# Root Mean Squared Error-->: 5.333941414776711

# %% [markdown]
# #### Ridge

# %%
RIG.fit(X_train, Y_train)
y_pred = RIG.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.9285318126449388

# %%
y_pred_testRIG  = RIG.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testRIG ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.7576913531948894

# %%
mae = mean_absolute_error(Y_test, y_pred_testRIG)
mse = mean_squared_error(Y_test, y_pred_testRIG)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 4.926053532257805
# Mean Squared Error -->: 36.81577002395149
# Root Mean Squared Error-->: 6.067600021750897

# %% [markdown]
# #### Support vector model (svm)

# %%
SVM.fit(X_train, Y_train)
y_pred = SVM.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.20917745204355165

# %%
y_pred_testSVM  = SVM.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testSVM ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.04308712587182284

# %%
mae = mean_absolute_error(Y_test, y_pred_testSVM)
mse = mean_squared_error(Y_test, y_pred_testSVM)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 10.653232895635991
# Mean Squared Error -->: 145.39094981284993
# Root Mean Squared Error-->: 12.057816958838359

# %% [markdown]
# #### Linear Regression

# %%
LR.fit(X_train, Y_train)
y_pred = LR.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.9392808384454875

# %%
y_pred_testLR  = LR.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testLR ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.7647325319768948

# %%
mae = mean_absolute_error(Y_test, y_pred_testLR)
mse = mean_squared_error(Y_test, y_pred_testLR)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 5.144876411583272
# Mean Squared Error -->: 35.74595092276054
# Root Mean Squared Error-->: 5.978791761113657

# %% [markdown]
# #### DecisionTreeRegressor

# %%
DTR.fit(X_train, Y_train)
y_pred = DTR.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 1.0

# %%
y_pred_testDTR  = DTR.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testDTR ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.7030028794734677

# %%
mae = mean_absolute_error(Y_test, y_pred_testDTR)
mse = mean_squared_error(Y_test, y_pred_testDTR)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 5.625
# Mean Squared Error -->: 45.125
# Root Mean Squared Error-->: 6.7175144212722016

# %% [markdown]
# #### AdaBoost Regressor

# %%
abr.fit(X_train, Y_train)
y_pred = abr.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.9933420393949287

# %%
y_pred_testABR  = abr.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testABR ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.6844425415853987

# %%
mae = mean_absolute_error(Y_test, y_pred_testABR)
mse = mean_squared_error(Y_test, y_pred_testABR)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 6.226190476190476
# Mean Squared Error -->: 47.94501133786848
# Root Mean Squared Error-->: 6.9242336281980315

# %% [markdown]
# #### Random Forest Regressor

# %%
RFR.fit(X_train, Y_train)
y_pred = RFR.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.9260062520404833

# %%
y_pred_testRFR  = RFR.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testRFR ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.5900273138626081

# %%
mae = mean_absolute_error(Y_test, y_pred_testRFR)
mse = mean_squared_error(Y_test, y_pred_testRFR)
rmse = np.sqrt(mse)

print("Mean Absolute Error-->", mae)
print("Mean Squared Error -->:", mse)
print("Root Mean Squared Error-->:", rmse)
# Out:
# Mean Absolute Error--> 7.18
# Mean Squared Error -->: 62.290224999999985
# Root Mean Squared Error-->: 7.892415663154088

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cscore1 = cross_val_score(LS,X,Y)
print('Cscore for Lasso-> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testLS)-cscore1.mean())
# Out:
# Cscore for Lasso->  [ 0.74709618 -1.04544966  0.77039332  0.78513235  0.87723793]
# mean of cscore->  0.4268820240388041
# difference between R2 and cross validation score is 0.362423857203287

# %%
cscore1 = cross_val_score(abr,X,Y)
print('Cscore for AdaBoost Regressor-> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testABR)-cscore1.mean())
# Out:
# Cscore for AdaBoost Regressor->  [ 0.29330937 -6.13736842  0.41194756  0.53383868  0.89147258]
# mean of cscore->  -0.8013600459884106
# difference between R2 and cross validation score is 1.4858025875738092

# %%
cscore1 = cross_val_score(LR,X,Y)
print('Cscore for Linaer Regression -> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testLR)-cscore1.mean())
# Out:
# Cscore for Linaer Regression ->  [ 0.59960667 -1.04852042  0.63023213  0.56003545  0.7367276 ]
# mean of cscore->  0.2956162841694411
# difference between R2 and cross validation score is 0.46911624780745376

# %%
cscore1 = cross_val_score(RIG,X,Y)
print('Cscore for RIDGE-> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testRIG)-cscore1.mean())
# Out:
# Cscore for RIDGE->  [ 0.59967223 -1.24934118  0.66658864  0.89872169  0.87120873]
# mean of cscore->  0.35737002209555263
# difference between R2 and cross validation score is 0.4003213310993368

# %%
cscore1 = cross_val_score(SVM,X,Y)
print('Cscore for Support Vector Model -> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testABR)-cscore1.mean())
# Out:
# Cscore for Support Vector Model ->  [-0.10238097 -1.21049704 -0.01843886 -0.47226586  0.16186819]
# mean of cscore->  -0.3283429068070836
# difference between R2 and cross validation score is 1.0127854483924823

# %%
cscore1 = cross_val_score(DTR,X,Y)
print('Cscore for Decision Tree Regressor -> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testDTR)-cscore1.mean())
# Out:
# Cscore for Decision Tree Regressor ->  [-1.68295455 -9.42105263  0.300711    0.38032787 -0.58313679]
# mean of cscore->  -2.2012210202104194
# difference between R2 and cross validation score is 2.9042238996838874

# %%
cscore1 = cross_val_score(RFR,X,Y)
print('Cscore for RandomForest Regressor-> ',cscore1)
print('mean of cscore-> ',cscore1.mean())
print('difference between R2 and cross validation score is',r2_score(Y_test,y_pred_testRFR)-cscore1.mean())
# Out:
# Cscore for RandomForest Regressor->  [ 0.36490614 -5.32714868  0.38854872  0.36495492  0.85926327]
# mean of cscore->  -0.6698951277843128
# difference between R2 and cross validation score is 1.2599224416469208

# %% [markdown]
# here we choose Lasso based on Cscore and train and test data

# %% [markdown]
# ## Hyper parameter tuning

# %%
LS.get_params().keys()
# Out:
# dict_keys(['alpha', 'copy_X', 'fit_intercept', 'max_iter', 'normalize', 'positive', 'precompute', 'random_state', 'selection', 'tol', 'warm_start'])

# %%
parameters = {
    'alpha': [0.1, 0.5, 1.0],  
    'fit_intercept': [True, False],
    'precompute': [False],  
    'copy_X': [True, False],
    'max_iter': [500, 1000, 1500],  
    'tol': [1e-3, 1e-4, 1e-5]  
}

# %%
GSC = GridSearchCV(Lasso(),parameters,cv= 5)

# %%
GSC.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 0.5, 1.0], 'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'max_iter': [500, 1000, 1500], 'precompute': [False],
#                          'tol': [0.001, 0.0001, 1e-05]})

# %%
GSC.best_params_
# Out:
# {'alpha': 0.5,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 500,
#  'precompute': False,
#  'tol': 0.001}

# %%
LS_final=Lasso(alpha= 0.5,copy_X= True, fit_intercept= True, max_iter= 500, precompute= False, tol= 0.001)
LS_final.fit(X_train, Y_train)
y_pred = LS_final.predict(X_train)
R2_score = r2_score( Y_train,y_pred ) # checking train data 
print("r2 score of trained data--->",R2_score)
# Out:
# r2 score of trained data---> 0.8897890865725933

# %%
y_pred_testLS  = LS_final.predict(X_test)
R2_score = r2_score( Y_test, y_pred_testLS ) # checking test data 
print('r2 score of test data--->', R2_score)
# Out:
# r2 score of test data---> 0.8127458263018005

# %% [markdown]
# ## Model Saving

# %%
import joblib
joblib.dump(LS_final, 'Baseball Case Study')
# Out:
# ['Baseball Case Study']

# %% [markdown]
# # Prediction

# %%
mymodel = joblib.load('Baseball Case Study')
prdt = mymodel.predict(X_test)
prdt
# Out:
# array([71.27786858, 64.3698996 , 86.16731901, 77.98873677, 83.43812549,
#        87.36216894, 82.13142869, 90.96712452])

# %% [markdown]
# ## comparing from original

# %%
Orginal = np.array(Y_test)
data1 = pd.DataFrame({'predicted': prdt,'original':Orginal})
data1
# Out:
#    predicted  original
# 0  71.277869        67
# 1  64.369900        63
# 2  86.167319        97
# 3  77.988737        76
# 4  83.438125        83
# 5  87.362169        92
# 6  82.131429        86
# 7  90.967125        98

# %% [markdown]
# hence we can see that our model approximately predicted most of the values
